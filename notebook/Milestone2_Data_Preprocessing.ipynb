# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Telco-Churn-Project
# Out:
# /content/drive/MyDrive/Telco-Churn-Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data/Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# MISSING VALUES

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# DUPLICATE ROWS

# %%
df.describe().sum()
# Out:
# SeniorCitizen     7044.530758
# tenure            7264.930630
# MonthlyCharges    7470.551740
# dtype: float64

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
for col in df.columns:
  print(col,df[col].nunique())
# Out:
# customerID 7043
# gender 2
# SeniorCitizen 2
# Partner 2
# Dependents 2
# tenure 73
# PhoneService 2
# MultipleLines 3
# InternetService 3
# OnlineSecurity 3
# OnlineBackup 3
# DeviceProtection 3
# TechSupport 3
# StreamingTV 3
# StreamingMovies 3
# Contract 3
# PaperlessBilling 2
# PaymentMethod 4
# MonthlyCharges 1585
# TotalCharges 6531
# Churn 2

# %% [markdown]
# DATA CLEANING

# %%
df.drop("customerID", axis=1, inplace = True)

# %%
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors="coerce")

# %%
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df['TotalCharges'].fillna(df['TotalCharges'].median(),inplace=True)
# Out:
# /tmp/ipykernel_2541/3929950690.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TotalCharges'].fillna(df['TotalCharges'].median(),inplace=True)

# %% [markdown]
# GRAPHS

# %%
sns.countplot(x='Churn', data=df)
plt.title("Churn Distribution")
plt.savefig("results/EDA_graphs/Churn_distribution.png")
plt.show()

# %%
# GENDER VS CHURN

sns.countplot(x='gender', hue = "Churn", data=df)
plt.title("Gender vs Churn Graph")
plt.savefig("results/EDA_graphs/Gender_vs_Churn.png")
plt.show()

# %%
#CONTRACT VS CHURN

sns.countplot(x='Contract', hue='Churn', data=df)
plt.title("Contract vs Churn")
plt.savefig("results/EDA_graphs/Contract_vs_Churn.png")
plt.show()

# %%
#INTERNET SERVICE VS CHURN

sns.countplot(x='InternetService', hue='Churn', data=df)
plt.title("Internet Service vs Churn Graph")
plt.savefig("results/EDA_graphs/Internet_Service_vs_Churn.png")
plt.show()

# %%
#PAYMENT MODE GRAPH

sns.countplot(x='PaymentMethod', hue='Churn', data=df)
plt.title("Payment Method vs Churn Graph")
plt.savefig("results/EDA_graphs/Payment_Method_vs_Churn.png")
plt.show()

# %% [markdown]
# HISTOGRAM

# %%
plt.hist(df['MonthlyCharges'])
plt.title("Monthly Charges Graph")
plt.xlabel("Monthly Charges")
plt.ylabel("Freq")
plt.savefig("results/EDA_graphs/Monthly_Charges_Graph.png")
plt.show()

# %%
plt.hist(df['tenure'])
plt.title("Tenure Graph")
plt.xlabel("Tenure")
plt.ylabel("Freq")
plt.savefig("results/EDA_graphs/Tenure Graph.png")
plt.show()

# %%
x = df.drop('Churn', axis=1)
y = df['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2142  Female              0      No        Yes      21          Yes
# 1623  Female              0      No         No      54          Yes
# 6074    Male              0     Yes         No       1           No
# 1362    Male              0      No         No       4          Yes
# 6754    Male              0      No        Yes       0          Yes
# ...      ...            ...     ...        ...     ...          ...
# 3772    Male              0     Yes         No       1          Yes
# 5191  Female              0     Yes        Yes      23          Yes
# 5226    Male              0     Yes        Yes      12          Yes
# 5390    Male              1      No         No      12          Yes
# 860     Male              0      No         No      26          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 2142                No             DSL                  Yes
# ...

# %%
X_test
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 185   Female              0     Yes         No       1           No
# 2715    Male              0      No         No      41          Yes
# 3825  Female              0     Yes        Yes      52          Yes
# 1807  Female              0      No         No       1          Yes
# 132     Male              0      No         No      67          Yes
# ...      ...            ...     ...        ...     ...          ...
# 6366  Female              0     Yes         No      64          Yes
# 315     Male              0     Yes        Yes      51          Yes
# 2439    Male              0     Yes        Yes      17          Yes
# 5002  Female              0     Yes        Yes      69           No
# 1161    Male              0      No        Yes       1           No
#
#          MultipleLines InternetService       OnlineSecurity  \
# 185   No phone service             DSL                   No
# ...

# %%
y_train
# Out:
# 2142     No
# 1623     No
# 6074    Yes
# 1362    Yes
# 6754     No
#        ...
# 3772    Yes
# 5191     No
# 5226     No
# 5390    Yes
# 860      No
# Name: Churn, Length: 5634, dtype: object

# %%
y_test
# Out:
# 185     Yes
# 2715     No
# 3825     No
# 1807    Yes
# 132      No
#        ...
# 6366     No
# 315      No
# 2439     No
# 5002     No
# 1161    Yes
# Name: Churn, Length: 1409, dtype: object

# %%
X_train.to_csv("results/final_data/X_train.csv", index = False)

# %%
X_test.to_csv("results/final_data/X_test.csv", index = False)

# %%
y_train.to_csv("results/final_data/y_train.csv", index = False)

# %%
y_test.to_csv("results/final_data/y_test.csv", index = False)
